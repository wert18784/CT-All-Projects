# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

import numpy as np
import matplotlib.pyplot as plt
import os
import cv2

from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

from tqdm import tqdm

# %%
model = tf.keras.models.load_model('saved_model\my_model')

# %%
DATADIR = r"F:\Projects\learn\deep learning\convnet\Aug_20"
CATEGORIES = [str(i) for i in os.listdir(DATADIR)]
prediction_dict = dict(zip([i for i, j in enumerate(CATEGORIES)],CATEGORIES))

CATEGORIES
# Out:
# ['AMERICAN GOLDFINCH',
#  'BLACK-CAPPED CHICKADEE',
#  'CALIFORNIA GULL',
#  'CHIPPING SPARROW',
#  'CROW',
#  'DARK EYED JUNCO',
#  'DOWNY WOODPECKER',
#  'EASTERN BLUEBIRD',
#  'GOLDEN EAGLE',
#  'HOUSE FINCH',
#  'HOUSE SPARROW',
#  'MOURNING DOVE',
#  'NORTHERN CARDINAL',
#  'NORTHERN MOCKINGBIRD',
#  'RED HEADED WOODPECKER',
#  'ROBIN',
#  'ROCK DOVE',
#  'RUBY THROATED HUMMINGBIRD',
#  'TIT MOUSE',
#  'WOOD DUCK']

# %%
def decode_prediction(arr):
    out = []
    for i in arr:
        new = sorted(list(i))[-3:]
        for j in new:
            out.append(prediction_dict[list(i).index(j)])
    print("Top 3 Predictions")
    return out[::-1]

# %%
URL = 'https://www.wildlifeillinois.org/wp-content/uploads/2018/12/American-Crow.jpeg'
img_path = tf.keras.utils.get_file('bird.jpg', URL)


img_array = cv2.imread(img_path)
IMG_SIZE = 75
img_array = cv2.resize(img_array, (IMG_SIZE, IMG_SIZE))
img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
img_array = np.array(img_array)

plt.imshow(img_array)


x = img_array.reshape(-1, IMG_SIZE, IMG_SIZE, 3)

os.remove(img_path)
# Out:
# Downloading data from https://www.wildlifeillinois.org/wp-content/uploads/2018/12/American-Crow.jpeg
# 335872/332206 [==============================] - 0s 0us/step

# %%
prediction = model.predict(x)
decode_prediction(prediction)
# Out:
# Top 3 Predictions
# ['CROW', 'RED HEADED WOODPECKER', 'ROCK DOVE']

# %%
# Out:
# INFO:tensorflow:Assets written to: saved_model/my_model.hd5\assets
